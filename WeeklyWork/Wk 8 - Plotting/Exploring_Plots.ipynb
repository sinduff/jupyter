# %% [markdown]
# # Exploring Plots
#
# ***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#style sheets .. reference https://matplotlib.org/3.1.1/gallery/style_sheets/style_sheets_reference.html
plt.style.use("ggplot")

# %%
plt.plot([1,2,3], "r-", label="red line")
plt.legend()

# %%
fig, ax = plt.subplots()
ax.plot([1,2,3], "r-", label="Red Line")
ax.legend()

# %% [markdown]
# ### Video 2 - Seaborn Plots
#
# Reference - https://seaborn.pydata.org/tutorial/relational.html
# <br>
# Seaborn Themes - https://seaborn.pydata.org/tutorial/aesthetics.html
# <br>
# #### From the seaborn tutorial

# %%
x = np.linspace(0.0,100.0,10) 
y = x**2
sns.relplot(x=x, y=y);
#sns.relplot(x="xLine", y="yLine");
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-b4dee652f788> in <module>
#       1 x = np.linspace(0.0,100.0,10)
#       2 y = x**2
# ----> 3 sns.relplot(x=x, y=y);
#       4 #sns.relplot(x="xLine", y="yLine");
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#    1685     # Set up the FacetGrid object
#    1686     facet_kws = {} if facet_kws is None else facet_kws
# -> 1687     g = FacetGrid(
#    1688         data=data, row=row, col=col, col_wrap=col_wrap,
#    1689         row_order=row_order, col_order=col_order,
#
# ...

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(x="timepoint", y="signal", ci=None, kind="line", data=fmri);

# %% [markdown]
# ### Video 3 - Distributions and category plots
# <br>
# #### Distplots

# %%
x = np.random.normal(1, 2, 1000)

# %%
sns.distplot(x, kde=True)

# %% [markdown]
# #### Plotting with Categorical Data

# %%
#titanic dataset preloaded with Seaborn
titanic = sns.load_dataset("titanic")
sns.catplot(x="sex", y="survived", hue="class", kind="bar", data=titanic)

# %% [markdown]
# #### Bar Chart

# %%
makes = ["Toyota", "Skoda", "VW", "BMW"]
car = np.random.choice(makes,10)
list(car)
# Out:
# ['Toyota', 'Toyota', 'VW', 'Skoda', 'VW', 'BMW', 'Toyota', 'Skoda', 'VW', 'VW']

# %%
sns.catplot(x="car")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-3911faef4209> in <module>
# ----> 1 sns.catplot(x="car")
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3721     # facets to ensure representation of all data in the final plot
#    3722     p = _CategoricalPlotter()
# -> 3723     p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3724     order = p.group_names
#    3725     hue_order = p.hue_names
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     150                 if isinstance(var, str):
# ...
